# %%
# -*- coding: utf-8 -*-

path = 'core_SUW.txt'

#path = 'test.txt'

import pandas as pd


df = pd.read_table(path, header = None)
df = df.iloc[::-1]

result = pd.Series()

flag = True
buf = ''
for index, row in df.iterrows():
 

    if '動詞' in row[16] and '助動詞' not in row[16] and '感動詞' not in row[16]:
        buf = row[12]

        flag = False
        
    else:
        pass
    
    if '名詞' in row[16] and '代名詞' not in row[16]:
        
        if flag == False:
            buf = row[12] + buf    
            print("hoge")
    else:
        flag = True
        try:
            result[buf] += 1
        except KeyError:
            result[buf] = 1
        buf = ''
 
res = result.sort_values(ascending = False)
res.to_csv('result.csv')



print("end")
# Out:
# end
# C:\Users\hinat\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.

# %%
res2 = pd.Series()

for i, v in res.iteritems():
    if ren(i) > 2:
        res2[i] = v
        
res2.to_csv('result2.csv')
# Out:
# 為る
# 居る
# 有る
# 言う
# 成る
# 来る
# 見る
# 出来る
# 因る
# 行く
# 思う
# つく
# 行う
# 於く
# 対する
# 考える
# 仕舞う
# 使う
# 分かる
# 持つ
# 遣る
# 取る
# 出る
# 作る
# 聞く
# 入る
# 関する
# 呉れる
# 下さる
# 知る
# 受ける
# 置く
# 貰う
# 出す
# 図る
# 書く
# 付ける
# 見える
# 得る
# 掛ける
# 掛かる
# 上げる
# 始める
# 入れる
# 食べる
# 買う
# 知れる
# 教える
# 付く
# 求める
# 続ける
# 続く
# 感ずる
# 話す
# 開く
# 切る
# 変わる
# 示す
# 過ぎる
# 加える
# 呼ぶ
# 生きる
# 進める
# 違う
# 向ける
# 認める
# 進む
# 読む
# 返る
# 含む
# 増える
# 立つ
# 頂く
# 通ずる
# 決める
# 合わせる
# 目指す
# 始まる
# 乗る
# 基づく
# 与える
# 送る
# 越える
# 変える
# 歩く
# 取り組む
# 残る
# 終わる
# 語る
# 待つ
# 当たる
# 応ずる
# 願う
# 働く
# 守る
# 飲む
# 渡る
# 伝える
# 楽しむ
# 止める
# 会う
# 走る
# 死ぬ
# 選ぶ
# 答える
# 関わる
# 述べる
# 向かう
# 生まれる
# 戻る
# 見せる
# 動く
# 起きる
# 比べる
# 頑張る
# 含める
# 伴う
# 勧める
# 描く
# 打つ
# 上がる
# 巡る
# 住む
# 起こす
# 並ぶ
# 決まる
# 迎える
# 忘れる
# 踏まえる
# 繋がる
# 残す
# 除く
# 広がる
# 上る
# 起こる
# 調べる
# 探す
# 失う
# 学ぶ
# 立てる
# 払う
# 訪れる
# 占める
# 集める
# 離れる
# 乗せる
# 減る
# 許す
# 売る
# 努める
# 纏める
# 果たす
# 取れる
# 異なる
# 集まる
# 現われる
# 無くなる
# 着る
# 済む
# 支払う
# 気付く
# 有する
# 覚える
# 支える
# 歌う
# 流れる
# 従う
# 合う
# 高まる
# 抱える
# 繰り返す
# 笑う
# 通す
# 触れる
# 似る
# 受け入れる
# 問う
# 暮らす
# 思い出す
# 驚く
# 引く
# 御座る
# 捨てる
# 見付ける
# 回る
# 遊ぶ
# 運ぶ
# 為さる
# 至る
# 消える
# 迫る
# 経つ
# 限る
# 生む
# 落ちる
# 聞こえる
# 連れる
# 殺す
# 生ずる
# 目立つ
# 届く
# 設ける
# 定める
# 経る
# 捕らえる
# 勤める
# 押さえる
# 用いる
# 生かす
# 寝る
# 振る
# 困る
# 喜ぶ
# 差す
# 達する
# 掲げる
# 信ずる
# 下りる
# 押す
# 伸びる
# 結ぶ
# 通う
# 勝つ
# 優れる
# 抜く
# 戦う
# 狙う
# 流す
# 及ぶ
# 張る
# 避ける
# 過ごす
# 開ける
# 飛ぶ
# 外す
# 奪う
# 返す
# 負ける
# 交ぜる
# 抱く
# 出会う
# 留まる
# 要する
# 伸ばす
# 扱う
# 組む
# 売れる
# 育てる
# 渡す
# 追う
# 備える
# 訴える
# 借りる
# 成す
# 茹でる
# 見付かる
# 頼む
# 兼ねる
# 座る
# 落とす
# 伝わる
# 逃げる
# 引き続く
# 資する
# 疲れる
# 着く
# 下げる
# 眺める
# 齎す
# 泣く
# 上回る
# 防ぐ
# 食う
# 吐く
# 止まる
# 悩む
# 表わす
# 次ぐ
# 利く
# 重ねる
# 動かす
# 高める
# 掴む
# 眠る
# 出掛ける
# 怒る
# 愛する
# 広げる
# 叫ぶ
# 振り返る
# 込める
# 隠す
# 盛り込む
# 望む
# 亡くなる
# 取り上げる
# 下がる
# 終える
# 減らす
# 増す
# 分ける
# 慣れる
# 寄せる
# 育つ
# 致す
# 溢れる
# 担う
# 休む
# 増やす
# 急ぐ
# 尽くす
# 任せる
# 焼く
# 止む
# 積む
# 握る
# 促す
# 浮かぶ
# 近付く
# 講ずる
# 断る
# 諦める
# 見掛ける
# 付き合う
# 遅れる
# 襲う
# 誘う
# 耐える
# 別れる
# 受け取る
# 演ずる
# 通る
# 抜ける
# こだわる
# 繋ぐ
# 構う
# 洗う
# 突く
# 助ける
# 欠かす
# 落ち着く
# 飾る
# 移す
# 見込む
# 泳ぐ
# 保つ
# 絡む
# 戻す
# 当てる
# 響く
# 降る
# がる
# 破る
# 打ち出す
# 味わう
# 負う
# 取り入れる
# 窺う
# 叩く
# 沿う
# 空く
# 持ち込む
# 貸す
# 強める
# 揃う
# 呟く
# 築く
# 揃える
# 足りる
# 頷く
# 恐れる
# 直す
# 浴びる
# 囲む
# 倒れる
# 見詰める
# 訪ねる
# 引っ張る
# 要る
# 包む
# 試す
# 強まる
# 放つ
# 呼び掛ける
# 並べる
# 殴る
# 深める
# 膨らむ
# 疑う
# 招く
# 頼る
# 外れる
# 確かめる
# 接する
# 向く
# いらっしゃる
# 記す
# 間違う
# 盛る
# 加わる
# 探る
# 覆う
# 分かれる
# 見直す
# 尋ねる
# 満たす
# 閉じる
# 直る
# 手伝う
# 呼び出す
# 揺れる
# 立ち上がる
# 咲く
# 臨む
# 茹で上がる
# 締める
# 回す
# 喋る
# 挟む
# 詰まる
# 控える
# 褒める
# 取り出す
# 交わす
# 生み出す
# 乗り込む
# 鍛える
# 沸く
# 捲る
# 収まる
# 届ける
# 鳴る
# 迷う
# 消す
# 役立つ
# 輝く
# 刻む
# 覗く
# 傾ける
# 吸う
# 隠れる
# 慌てる
# 数える
# 反する
# 整う
# 漂う
# 祈る
# 報ずる
# 投げる
# 熟す
# 辿り着く
# 収める
# 吹く
# 沸かす
# 絞る
# 埋める
# 取り戻す
# 拭く
# 及ぼす
# 越す
# 下ろす
# 固める
# 際する
# 整える
# 追い込む
# 明かす
# 移る
# 題する
# 傷付ける
# 崩れる
# 添える
# 踏む
# 争う
# 贈る
# 作り上げる
# 重なる
# 触る
# 見上げる
# 陥る
# 話し合う
# 戸惑う
# 被る
# 切れる
# 下回る
# 転ずる
# 苦しむ
# 競う
# 堪る
# 施す
# 飛び出す
# 落ち込む
# 作り出す
# 炒める
# 捕まる
# 溜まる
# 告げる
# 命ずる
# 絶える
# 滑る
# 光る
# 塗る
# 痩せる
# 吊る
# 組み合わせる
# 引き下げる
# 植える
# 辿る
# 嫌う
# 配る
# 寄る
# 泊まる
# 恵まれる
# 継ぐ
# 掻く
# 磨く
# 駆け付ける
# 見送る
# 携わる
# 乗り出す
# 犯す
# 発する
# 引き受ける
# 繰り広げる
# 履く
# 誇る
# 倒す
# 去る
# 即する
# 飼う
# 尽きる
# 無くす
# 引き継ぐ
# 親しむ
# 蘇る
# 謝る
# 稼ぐ
# 募る
# 嵌まる
# 乗り越える
# 盛り上げる
# 見なす
# 混ぜ合わせる
# 巻く
# 取り巻く
# 裏切る
# 離す
# 潰す
# 嘆く
# 手掛ける
# 飛び込む
# 晒す
# 折れる
# 欠ける
# 騒ぐ
# 盛り上がる
# 導く
# 壊れる
# 心掛ける
# 預ける
# 引き出す
# 敗れる
# 割れる
# 割る
# 説く
# 敷く
# 騙す
# 受け止める
# 捕まえる
# 照らす
# 課する
# 黙る
# 浮く
# 背負う
# 詰める
# 属する
# 構える
# 壊す
# 崩す
# 埋まる
# 映る
# 打ち込む
# 注ぐ
# 追い付く
# 率いる
# 改める
# 仕上げる
# 取り付ける
# 強いる
# 写る
# 思い掛ける
# 思い付く
# 追い掛ける
# 覚める
# 痛む
# 流行る
# 攻める
# 取り込む
# 解く
# 好む
# 挑む
# 救う
# 書き込む
# 出来上がる
# 見出だす
# 浸る
# 憧れる
# 弾む
# 晴れる
# 削る
# 取り除く
# 振り込む
# 傾く
# 断つ
# 踊る
# 飛ばす
# 下す
# 振るう
# 例える
# 譲る
# 伺う
# 撒く
# 押し付ける
# 雇う
# 溜める
# ぶつかる
# 破れる
# 痛める
# 引き上げる
# 貫く
# 温める
# 持ち出す
# 拒む
# 見極める
# 思い込む
# 見合う
# 見渡す
# 知り合う
# 溶ける
# 裏付ける
# 抜け出す
# 打ち明ける
# 受け継ぐ
# 浮かべる
# 踏み込む
# 縫う
# 染みる
# 漏れる
# 纏まる
# 呈する
# 働き掛ける
# 売り出す
# 切り替える
# 営む
# 買い取る
# 潜る
# 成り立つ
# 曲がる
# 擦る
# 脅す
# 名付ける
# 誓う
# 逃す
# 汚れる
# 唱える
# 語り合う
# 飽きる
# 繋げる
# 縛る
# 申し上げる
# 練る
# 焦る
# 間違える
# 冷やす
# 放る
# 差し出す
# 励ます
# 癒す
# 濡れる
# ずれる
# 拭う
# 賑わう
# 振る舞う
# 遂げる
# 見下ろす
# 結び付ける
# 向き合う
# 名乗る
# 据える
# 測る
# 話し掛ける
# 申し込む
# 暴れる
# 間に合う
# 浮かび上がる
# 禁ずる
# 写す
# 切り出す
# 馴染む
# 言い渡す
# 養う
# 仕入れる
# 揉む
# 劣る
# 埋め込む
# 脱ぐ
# 見逃す
# 満ちる
# 仕掛ける
# 生える
# 似合う
# 冷める
# 走り回る
# 結び付く
# 追い詰める
# 足る
# 乗り切る
# 亡くす
# 跨がる
# 余る
# 因む
# 補う
# 制する
# 誤る
# 取り纏める
# 見分ける
# 見舞う
# 拾う
# 果てる
# 称する
# 培う
# 取り扱う
# 逆らう
# 傷付く
# 適する
# 熱する
# 祝う
# 逃れる
# 俯く
# 脱する
# 引き起こす
# 習う
# 薄れる
# 盗む
# 逃げ出す
# 浸ける
# 押し出す
# ちぎる
# 振り回す
# 凌ぐ
# 思い切る
# 訳す
# 巻き込む
# 引き締める
# 付け加える
# 儲ける
# 見当たる
# 投ずる
# 積み上げる
# 打ち上げる
# 富む
# 駆け込む
# 歩む
# 組み立てる
# 散らす
# 弾く
# 苛める
# 荒れる
# 和らげる
# 固まる
# 剥く
# 目覚める
# 薄める
# 生き残る
# 遡る
# 物語る
# 下る
# 遮る
# 囁く
# ぶつける
# 滲む
# 擦れ違う
# 転ぶ
# 乱れる
# 装う
# 太る
# 切り開く
# 潰れる
# 踏み出す
# 見守る
# 立ち上げる
# 澄む
# 助かる
# 言い切る
# 踏み切る
# 先立つ
# 留める
# 請け負う
# 持ち上げる
# 引き摺る
# 仰る
# 見回す
# 噛む
# 煽る
# 仕留める
# 参る
# 凹む
# 入り込む
# 飢える
# 交える
# 賄う
# 担ぐ
# 込む
# 受け付ける
# 切り取る
# 微笑む
# 震える
# 捕らわれる
# 問い合わせる
# 正す
# 綴る
# ばれる
# 甘える
# 剥がす
# 指差す
# 聞かす
# 委ねる
# 銜える
# 然り
# 張り付ける
# 沈む
# 染める
# あしらう
# 押し込む
# 吹き出す
# 持ち帰る
# 見据える
# 鳴く
# 引き取る
# 緩める
# 思い浮かべる
# 責める
# 気取る
# 配する
# 勝る
# 置き換える
# 決め込む
# 揺さぶる
# 捻る
# 取り囲む
# 立ち止まる
# 存ずる
# 書き替える
# 詰め込む
# 突き込む
# 弾ける
# 立ち寄る
# 思い立つ
# 暮れる
# 称える
# 育む
# 飛び交う
# 感じ取る
# 遣り直す
# 費やす
# 押し寄せる
# 被せる
# 衰える
# 弱る
# 慕う
# 語り掛ける
# 連ねる
# 試みる
# 絡める
# 満つ
# 曲げる
# 寛ぐ
# 帯びる
# 割り切る
# 凝らす
# 察する
# 乾く
# 引っ掛かる
# 切り離す
# 蹴る
# 免れる
# 送り込む
# 徹する
# 躊躇う
# 籠もる
# 移り住む
# 溶かす
# 片付ける
# 憎む
# 根付く
# 送り出す
# 芽生える
# 託する
# 漏らす
# 止す
# 堪える
# 差し込む
# 騙し取る
# 閉じ込める
# 叶う
# 触れ合う
# 仰ぐ
# 欠く
# 退ける
# 仕立てる
# 祭る
# 醸し出す
# 漕ぎ着ける
# 捜し出す
# 鳴らす
# 砕く
# 評する
# 瞑る
# 駆る
# 定まる
# そそる
# 先駆ける
# 出向く
# 損なう
# 際立つ
# 引っ掛ける
# 蒸す
# 論ずる
# 抱え込む
# 燃える
# 出迎える
# 受け持つ
# 焼ける
# 歪む
# 振り向く
# 取り替える
# 巻き上げる
# 揺らぐ
# めく
# 敵う
# 夢見る
# 妨げる
# 弱まる
# 枯れる
# 申す
# 冷える
# 足す
# 明ける
# 持ち合う
# 睨む
# 煮る
# 漕ぐ
# 染み込む
# 患う
# 立ち直る
# 伸び悩む
# 染まる
# 包み込む
# 鑑みる
# 準ずる
# 燃やす
# 打ち取る
# 知らす
# 長引く
# 突き付ける
# 組み込む
# 立ちはだかる
# 掘り出す
# 香る
# 安らぐ
# 手放す
# 酔っ払う
# 連なる
# 集う
# 惜しむ
# 描き出す
# 干す
# 細める
# 秘める
# 退く
# 建て替える
# 見せ付ける
# 歩き回る
# 引き付ける
# 流し送る
# 混ざる
# 腐る
# 塞ぐ
# 跨ぐ
# 差し上げる
# 嘗める
# 立ち入る
# 焚く
# 悼む
# 聞き取る
# 放り込む
# 切り上げる
# 立ち並ぶ
# 噛み締める
# 嗅ぐ
# 投げ込む
# 洒落る
# 積み重ねる
# 混む
# 馳せる
# 叶える
# 注ぎ込む
# 顰める
# 割り込む
# 抱き締める
# ごまかす
# 呆れる
# 途切れる
# 見落とす
# 投げ出す
# 売り込む
# 群がる
# 阻む
# 着替える
# 積み上がる
# 言い聞かせる
# 巡り会う
# 慰める
# 飲み込む
# 重んずる
# 住まう
# 駆け巡る
# 吊り上げる
# 差し伸べる
# 彩る
# 腰掛ける
# 剥がれる
# 打ち切る
# 粘る
# 深まる
# 立ち向かう
# 詰め替える
# 駆け出す
# 覗き込む
# 食い止める
# 読み上げる
# 介する
# 待ち受ける
# 怠る
# 掛け離れる
# 途絶える
# 待たす
# 撫でる
# 積み込む
# 顧みる
# 湧き出る
# 引き渡す
# 栄える
# 嵩む
# 折る
# 撥ねる
# 痺れる
# 舞う
# 汲む
# 駆け寄る
# 起き上がる
# 極める
# 逸れる
# 凝る
# 比する
# 和らぐ
# 申し立てる
# 乾かす
# 突き放す
# 苦しめる
# 催す
# 役立てる
# 出回る
# 読み取る
# 着せる
# 危ぶむ
# 冷え込む
# 偲ぶ
# 怒鳴る
# 叱る
# 葬る
# 恨む
# 買い上げる
# 省く
# 乗り換える
# 苛立つ
# 吐き出す
# ばむ
# 転がる
# 通り過ぎる
# 辞する
# 読み込む
# 散る
# 生まれ育つ
# 締め括る
# 持ち掛ける
# ぶつかり合う
# 化する
# 奪い取る
# 込み上げる
# 付する
# 見張る
# 捧げる
# 考え出す
# 生まれ変わる
# 潜める
# 行き着く
# 摘む
# 肥える
# 錆びる
# 見受ける
# 偏る
# 隔てる
# 躓く
# 仕切る
# 押し上げる
# 吹き飛ぶ
# 引っ越す
# 繰り出す
# 佇む
# 喘ぐ
# 売れ残る
# 容れる
# 汲み取る
# 擽る
# 和える
# 行き届く
# 垂れる
# 食い違う
# 競い合う
# 振り払う
# 通り抜ける
# 覚ます
# 掬う
# 伏せる
# 纏う
# 立たす
# 書き直す
# 握り締める
# 寄り添う
# 締め付ける
# 思い遣る
# 食らう
# 悟る
# 売り付ける
# 見遣る
# 追い出す
# 済ます
# 覆す
# 唸る
# 青褪める
# 突き上げる
# 涙ぐむ
# 嵌める
# 懐かしむ
# 潜む
# 広める
# 閉ざす
# 混じる
# くっ付く
# 差し掛かる
# ばてる
# 熟する
# 取り消す
# 彫る
# 嵩張る
# 尊ぶ
# 飛び下りる
# むかつく
# 垂らす
# 見過ごす
# 広まる
# ぶら下がる
# 過る
# 張り切る
# 掘る
# 駆ける
# 明く
# 裂く
# 教わる
# 切り捨てる
# 勝ち越す
# 汚す
# 切り分ける
# 転がす
# 茂る
# 手渡す
# 色褪せる
# 刈る
# 吹き込む
# 飛び立つ
# 掻き立てる
# 面する
# 曇る
# 送り付ける
# 支え合う
# 抜かす
# 驕る
# 見習う
# 取り残す
# 売り上げる
# 押し通す
# 飛び回る
# 萎える
# 緩む
# 遣り遂げる
# 沈める
# 映える
# 弱める
# 飛び散る
# 灯す
# 引き締まる
# 透ける
# 割り当てる
# 擦り下ろす
# 励む
# 根差す
# 執り行なう
# 口説く
# 言い替える
# 酔う
# 歪める
# もてる
# 駆け上がる
# 切り抜ける
# 湿る
# 律する
# 折り畳む
# 供する
# 否む
# 鈍る
# 動き回る
# 魅する
# 取り下げる
# 捏ねる
# 強請る
# 逸らす
# 突き進む
# 呼び止める
# 害する
# 吠える
# 突き立てる
# 取り締まる
# 断ずる
# 敷き詰める
# 冴える
# 波打つ
# 立ち返る
# 弄る
# 取り揃える
# 仕上がる
# しがみ付く
# 襲い掛かる
# 食い込む
# 買い換える
# 出直す
# 零れる
# 奏でる
# 差し引く
# 繰り上げる
# 孕む
# 近寄る
# 持て囃す
# 呼び寄せる
# ぶら下げる
# 脅かす
# 押し切る
# 纏わる
# 持ち上がる
# 投げ掛ける
# 仕える
# 蕩ける
# 戯れる
# 引き手繰る
# 巻き付ける
# 翻す
# 忍び込む
# 絡み合う
# ぱらつく
# 出でる
# 見返す
# 静まり返る
# 操る
# 突き刺す
# 気遣う
# 窶れる
# 掘り上げる
# 横たえる
# 向かい合う
# 差し押さえる
# 行き詰まる
# 乗り取る
# 仕分ける
# 売り越す
# 遠ざかる
# 積み立てる
# 解す
# 靡く
# 煮込む
# 齧り付く
# 赴く
# 喫する
# 転ける
# 事欠く
# 改まる
# 甘んずる
# 走り去る
# 吹き飛ばす
# 解ける
# 綻ぶ
# 積み増す
# 扮する
# 使い分ける
# 振れる
# 居座る
# 暴く
# 撓む
# 打っ掛ける
# 問い掛ける
# 締め出す
# 張り替える
# 分かち合う
# 罵る
# 引き立てる
# 貸し出す
# 陥れる
# 摩る
# 傾げる
# 滅ぶ
# 見破る
# 踏み入れる
# 這い上がる
# 攫う
# 巻き起こす
# 埋もれる
# さ迷う
# 吸い込む
# 儲かる
# 食する
# 廃れる
# 厭う
# 取り付く
# 刳り抜く
# ぼやける
# 丸める
# 零す
# 散らばる
# 通じ合う
# 生き延びる
# 聳える
# 駆け回る
# 占う
# 押し進める
# 切り落とす
# 遅らせる
# 銘ずる
# 騙る
# 給う
# 当て嵌まる
# 寄越す
# 抜き去る
# 持て余す
# 縋る
# 詰め掛ける
# 馬鹿げる
# 聞き返す
# 持ち歩く
# 濡らす
# 引き寄せる
# 恥じる
# 持ち合わせる
# 塞がる
# 巻き戻す
# 悩ます
# 形作る
# 願い出る
# 供える
# 奪い合う
# 並び立つ
# 押し退ける
# 焼き払う
# 付き纏う
# 見知る
# 見入る
# 目掛ける
# 閉じ籠もる
# 引き返す
# 譲り受ける
# 突き出す
# 溶け込む
# 放す
# 築き上げる
# 片付く
# 言い返す
# 背く
# 取り返す
# 引き延ばす
# 泣かす
# 飛び抜ける
# ばら蒔く
# 老いる
# 飲み干す
# 志す
# 流れ出す
# 咲き乱れる
# 従える
# 駆け下りる
# 澄ます
# 透き通る
# 掛け合う
# 勝ち取る
# 授かる
# 積もる
# 敬う
# だぶつく
# 出し合う
# 入れ替わる
# 渦巻く
# 略す
# 立て直す
# 引ける
# 束ねる
# 取り掛かる
# 任す
# 取り払う
# 踏み躙る
# 縮める
# 掘り下げる
# 睨み付ける
# 食み出す
# 縺れる
# 問い質す
# 滅ぼす
# 灯る
# 這う
# 慎む
# 絞り込む
# 言い表わす
# 愛でる
# 打ちのめす
# 拭き取る
# 偽る
# 和む
# 見比べる
# 括り付ける
# 持ち越す
# 凍る
# 尖る
# 息巻く
# そびれる
# 倣う
# 揉み合う
# 挽く
# 滲み出る
# 司る
# 乗り上げる
# 手繰る
# 割り出す
# 連れ去る
# 荒れ狂う
# 張り付く
# 科する
# 迫り来る
# 振り向ける
# 垣間見る
# 取り押さえる
# 乗り移る
# 勝ち上がる
# 着込む
# 取り外す
# 行き交う
# 持ち堪える
# 住み着く
# 押し入る
# 立ち込める
# 歩み寄る
# 織る
# めげる
# 処する
# 勤まる
# 静める
# 振り出す
# 勤しむ
# 醸す
# 詰め寄る
# 忍び寄る
# 送り届ける
# 翳す
# 威張る
# 縁取る
# 曝け出す
# 啄む
# 引き立つ
# 見切る
# 思い当たる
# 返り咲く
# 駆り立てる
# 食い下がる
# 育て上げる
# ぶれる
# 割り引く
# 擁する
# 出揃う
# 炊き込む
# 交じる
# 匂う
# 濁る
# 手繰り寄せる
# 愚図る
# 羨む
# 封じ込める
# 踏み固める
# 近付ける
# 裁く
# 紡ぐ
# 躍らす
# 付き添う
# 届け出る
# 連れ出す
# 呆れ返る
# 労う
# 突き止める
# 躱す
# 吹き付ける
# 吹き荒れる
# 蹲る
# 追い越す
# 浮き立つ
# 追い求める
# めかす
# 強張る
# 則る
# 駆け上る
# 切羽詰まる
# 思い知らす
# 年老いる
# 勢い付く
# 待ち構える
# 羽織る
# 見せ掛ける
# 投げ付ける
# 濁す
# 括る
# 膨れる
# 病む
# 実る
# 言い放つ
# ばらす
# 蹴散らす
# 挙る
# 引き分ける
# 立ち去る
# 溺れる
# 唆す
# 適う
# 企てる
# 瀕する
# 癒える
# 会する
# 作り直す
# 陣取る
# 召し上がる
# 申し入れる
# 揉み消す
# 弔う
# 考え付く
# 作り変える
# 早める
# 跳ね上がる
# 華やぐ
# 失せる
# 憤る
# 区切る
# 跪く
# 浸す
# 揺れ動く
# 休める
# 憚る
# 吹き抜ける
# 翻る
# 言い張る
# 書き上げる
# 書き出す
# 損ねる
# 当て嵌める
# 庇う
# 成し遂げる
# 背ける
# 寝付く
# 横たわる
# 取り分ける
# 捌く
# 思い浮かぶ
# 見立てる
# 思い止まる
# 預かる
# 狂う
# ときめく
# 嫁ぐ
# 潜り込む
# 掻き回す
# 遠退く
# 分け合う
# 見通す
# 咎める
# 噛み合う
# 差し向ける
# 申し出る
# 溜め込む
# 心行く
# 擬える
# 纏め上げる
# 突き返す
# 拝む
# 回り込む
# 寄せ付ける
# 放り出す
# 温まる
# 腫れる
# 見放す
# 引き離す
# 埋め立てる
# 仰け反る
# 押し潰す
# 決する
# 膨れ上がる
# 押さえ付ける
# 砕ける
# 考え直す
# 目論む
# 揉める
# 掃く
# 耕す
# 鏤める
# 打ち破る
# 取り合う
# 言い募る
# 引き込む
# 黒ずむ
# 焦げる
# 言い付ける
# 回し掛ける
# 見越す
# 焦がす
# 霞む
# 逝く
# 生み育てる
# 零れ落ちる
# 煮詰める
# 紛れる
# 垂れ流す
# 狙い澄ます
# 抱き抱える
# 解き明かす
# 引っ込める
# 見抜く
# ふざける
# 噛み付く
# 降り注ぐ
# 重ね合わせる
# 案ずる
# ちらつく
# 先んずる
# 怯える
# 舞い下りる
# 取り乱す
# 甘やかす
# 伸し掛かる
# 編む
# 諭す
# 竦める
# 身構える
# 助け合う
# 逃がす
# 模する
# 長ける
# 聳え立つ
# 静まる
# 毒付く
# からかう
# 投げ飛ばす
# 出会す
# 引き戻す
# 空ける
# 切り立つ
# 明け暮れる
# 凍り付く
# 見捨てる
# 振り翳す
# 犇めき合う
# 奥まる
# 飛び越える
# 追い回す
# 欺く
# 身籠もる
# 帰する
# 悔やむ
# 黙り込む
# 恐れ入る
# 憂える
# 突っ走る
# 覆い被さる
# 語らう
# 冠する
# 居合わせる
# 洗い流す
# 立ち行く
# 蓄える
# 煮出す
# 不貞腐れる
# しゃがみ込む
# 使い込む
# 旅立つ
# 溶く
# 余す
# 博する
# 喚く
# 古びる
# 抱き合う
# 躍り出る
# 悔いる
# 練り込む
# 刃向かう
# 拵える
# 怯む
# 奪い去る
# 研ぎ澄ます
# 仕込む
# 魘される
# 引き連れる
# 見紛う
# 魅せる
# 受け渡す
# ざわつく
# 匿う
# 寝かせる
# 組み上げる
# 呼び戻す
# 買い付ける
# ざわめく
# ずば抜ける
# 窺い知る
# 着飾る
# 赤茶ける
# 据え置く
# 結わえる
# 振り分ける
# 貪る
# 擦り減る
# 象る
# 貫き通す
# 引っこ抜く
# 訛る
# 色付く
# 染め上げる
# 囲う
# 打ちまける
# 注ぎ足す
# 結う
# 燃え立つ
# 遣らかす
# 呼び付ける
# 流れ出る
# 屈める
# 掠める
# 振り掛ける
# 踏み締める
# 娶る
# 築き直す
# 晴らす
# 授ける
# 押し戻す
# 借り入れる
# ぶらつく
# 落とし込む
# 乗り入れる
# そそり立つ
# 悪びれる
# 踏み止まる
# 取り壊す
# 振り上げる
# 開き直る
# 突き倒す
# 切り付ける
# ぶん殴る
# 見回る
# 横切る
# 食い付く
# 蔑む
# 燃え尽きる
# 掘り起こす
# なぞる
# 取り寄せる
# 怠ける
# 伸し上がる
# 打ち殺す
# 聞き比べる
# 食い荒らす
# 跳ねる
# 立ち会う
# 飛び上がる
# 切らす
# 弛む
# 掻き混ぜる
# 萌え出でる
# 纏い付く
# もがく
# 逸る
# 扇ぐ
# 滅びる
# 座する
# 白ける
# 引き替える
# 宿る
# 立ち尽くす
# 逃げ回る
# 高ずる
# 遣り過ごす
# 擦れる
# 居並ぶ
# 照れる
# 振り撒く
# ダブる
# 拱く
# 書き入れる
# 突き当たる
# 啜る
# 思い返す
# 吸い取る
# 生やす
# 呼び起こす
# 練り上げる
# 弄ぶ
# 口ずさむ
# 引き入れる
# 転がり込む
# 染め抜く
# 切り替わる
# 運び込む
# 下り立つ
# 思い至る
# 振り絞る
# 書き加える
# 問い返す
# 挟まる
# 突き落とす
# 買い込む
# くっ付ける
# 萎む
# 鞭打つ
# 北叟笑む
# 駆けずる
# 思い詰める
# 蠢く
# けちる
# 導き出す
# 追い抜く
# 脱ぎ捨てる
# 宥める
# 負ぶう
# 極まる
# 潜り抜ける
# 重なり合う
# 黙する
# 軋む
# 割り入れる
# 与する
# 炒め合わせる
# 濯ぐ
# 引き攣る
# 噎せる
# 読み返す
# 刈り取る
# 噛ます
# 浸かる
# 差し当たる
# 沈み込む
# 売り歩く
# 絡み付く
# 有り付く
# 遣り残す
# 寝惚ける
# 天下る
# 閃く
# 追い払う
# 押し当てる
# 吹き出る
# 擡げる
# ごった返す
# 流れ落ちる
# 釣り合う
# 報う
# 断ち切る
# 寝転ぶ
# 食い入る
# 植え替える
# 住み込む
# 口籠もる
# 目する
# 手間取る
# はにかむ
# 崇める
# 喜び勇む
# 兼ね備える
# 孵る
# 如く
# 巻き取る
# 震わせる
# 事故る
# 走り寄る
# 行き合う
# 立ち上る
# 嵌め込む
# 映し出す
# 滞る
# 眠り込む
# 過ぎ去る
# 飛び出る
# 似付く
# 蹌踉く
# 通り掛かる
# 設える
# 綴じる
# 薙ぐ
# 主立つ
# 媚びる
# 信じ込む
# 畳む
# 責め立てる
# 踏ん張る
# 齧る
# ずらす
# 合わす
# 飛び付く
# 沸き上がる
# 競り合う
# 反る
# 考え合わせる
# 上り詰める
# 張り巡らす
# 打ち壊す
# サボる
# 突っ伏す
# 持て成す
# 隣り合う
# 締め切る
# 植え付ける
# 流し込む
# 忍ぶ
# 撥ね上げる
# 救い出す
# 拗れる
# 押し掛ける
# 決め付ける
# 渋る
# 度重なる
# 彫り込む
# 映す
# 熟れる
# 蝕む
# 懲りる
# 擦り合わせる
# 沸き起こる
# 嘲笑う
# 張り出す
# もがき苦しむ
# 消え去る
# 引っ繰り返す
# ふらつく
# 居た堪れる
# 認め合う
# 惚れ込む
# 生る
# 座り込む
# 犇めく
# だらける
# 為合う
# 拾い集める
# 述べ立てる
# 思い悩む
# 買い揃える
# 黴びる
# 叩き落す
# 取り止める
# 侮る
# 塾れる
# 囲い込む
# 見積もる
# 崩れ落ちる
# 推し量る
# 治り掛ける
# 仄めかす
# 塗り重ねる
# 奏する
# 恵む
# 期する
# 合わせ持つ
# 書かす
# 取り直す
# 浴びせる
# 紛れ込む
# 溢れ返る
# 浮き上がる
# 瞬く
# 居着く
# 話し込む
# 見届ける
# 思い描く
# 贖う
# 盛り返す
# 浴する
# 動ずる
# 障る
# 遠ざける
# 揺らす
# 乗り合わせる
# 擦り付ける
# 買い戻す
# 捩る
# 果せる
# 連れ添う
# 真似る
# 苛む
# 言い残す
# 蹴り飛ばす
# 貶す
# 計り知れる
# 来す
# 買い越す
# 塗り替える
# 懲らしめる
# 嘯く
# あやす
# 剃る
# 捨て去る
# 端折る
# 吐き捨てる
# のめり込む
# 教え諭す
# 手控える
# 膿む
# 付け足す
# 泥濘む
# 失する
# 見透かす
# 悲しむ
# 考え込む
# 塗り込める
# 成り上がる
# 見返る
# 打っ壊れる
# 陰る
# 紐解く
# 驚かす
# 折り曲げる
# 歌い上げる
# 舞い上がる
# 蔓延る
# 投げ打つ
# 慈しむ
# 立ち竦む
# 泣き噦る
# 荒らす
# 眩む
# 潤う
# 咎め立てる
# 変わり行く
# 書き立てる
# 服する
# 着崩す
# 呼び覚ます
# 流れ込む
# 掻き集める
# 蒸かす
# 担ぎ出す
# 焦らす
# 削ぐ
# 好く
# 満ち満ちる
# 仕付ける
# 賑わす
# 振り返す
# 化ける
# 繕う
# 表する
# 剥ける
# 通い合う
# 思い合わせる
# 捜し回る
# 朽ちる
# 鳴り響く
# 練り歩く
# 報いる
# 任ずる
# 乗り継ぐ
# 入り乱れる
# 着回す
# 聞き出す
# 囃し立てる
# 吸い出す
# 訪ね歩く
# 言い立てる
# 追い遣る
# 蒔く
# 研ぐ
# 寂れる
# 思わす
# 読み解く
# 突き詰める
# 掘り当てる
# 力む
# 欲する
# 分かつ
# 罷り通る
# 切り返す
# 這い出す
# 迎え入れる
# 売り渡す
# 解する
# 打ち勝つ
# 晦ます
# 罹る
# 裂ける
# 勝ち残る
# 死する
# 見違える
# 嗅ぎ付ける
# 取り立てる
# 交わる
# 擦り込む
# 削り取る
# 書き下ろす
# 射止める
# 疎む
# 隠し持つ
# 合わさる
# 切り詰める
# 怒鳴り付ける
# しゃがむ
# 叩き付ける
# はだける
# 演じ分ける
# 光り輝く
# ぼったくる
# 食い合う
# 思い直す
# 均す
# きらめく
# 誘い出す
# 進み掛ける
# 引き下がる
# 口走る
# はぐらかす
# 作り合う
# 秘め置く
# 見開く
# 書き送る
# 転げ込む
# 押し合う
# 撫で付ける
# 突き立つ
# 並べ立てる
# 驚き悲しむ
# 攻め滅ぼす
# 下卑る
# 下り掛ける
# 泳ぎ疲れる
# 踏み違える
# 読み進む
# 買い与える
# 盗み出す
# 請う
# 叩き込む
# 這わす
# 仕る
# 宿す
# 打ち据える
# 思い余る
# 突き下ろす
# 仰ぎ見る
# 問い詰める
# 飛び退る
# 高鳴る
# 撓める
# かまける
# 湧き上がる
# 泳ぎ出す
# 払い落とす
# 睦み合う
# 搦め取る
# 突き合わせる
# 切り倒す
# 落ちぶれる
# 歩き掛ける
# 押し払う
# 労わる
# 射る
# 滅入る
# 窄まる
# 受け合う
# 鯱張る
# 気張る
# 引き合わす
# 来たる
# 長ずる
# 切り下ろす
# 折れ合う
# 真面目くさる
# 錆さす
# 蒸れる
# 焼き固める
# 滑り込む
# 取り除ける
# 持ち寄る
# 連れ立つ
# 画する
# 組み付く
# 飛び掛かる
# 突き飛ばす
# 見計らう
# 立て掛ける
# 建て替わる
# 歌い継ぐ
# 撓う
# 傾き掛ける
# 擦り付く
# へばり付く
# 賑わせる
# 寝そべる
# 引き払う
# 手子摺る
# 嘗め上げる
# 掴み出す
# 漂わす
# 連れ込む
# せがむ
# 欲張る
# 吊り下がる
# 縮こまる
# 申し合わせる
# 嗾ける
# 買わす
# 掻っ飛ぶ
# 垂れ下がる
# 戦わす
# 落ち延びる
# 為出かす
# 焼き付ける
# 浚える
# 握り潰す
# 申し伝える
# 組み分ける
# 破く
# 噛み砕く
# 溢れ出る
# 吊る下がる
# 取り置く
# 伝え残す
# 跳ね返す
# 下押す
# 承る
# 縛り付ける
# 使い惜しむ
# 与え合う
# 取り調べる
# 差し替える
# 高め合う
# 似通う
# 狭める
# 払い戻す
# 遊ばす
# 阿る
# 据え付ける
# 混み合う
# もげる
# 暴れ足りる
# 荒くれる
# 荒ぶる
# 買い求める
# 突き動かす
# 逃げ疲れる
# 探り辿る
# 結び合う
# 揺り動かす
# 崩れ去る
# 上り移る
# 引き裂く
# 戯れ合う
# 組み入れる
# 老ける
# 切り直す
# 立ち塞がる
# 扱き使う
# 睨める
# 去り行く
# 押し流す
# 織り交ぜる
# 運び上げる
# ロデる
# 立て籠る
# 暈かす
# 拾い出す
# 持ち戻る
# 移り変わる
# 打っ飛ばす
# 炙る
# 巡らす
# 言い触らす
# 秀でる
# 燻る
# 落っことす
# 払い除ける
# 慰め合う
# 焼き切る
# 切り刻む
# 生え変わる
# 擤む
# 惑わす
# 年取る
# 伝う
# 凭れる
# さす
# 乗り変わる
# 言い知れる
# ググる
# 蹴り込む
# 行き直す
# いかれる
# 削れる
# 馴れ合う
# 見下げる
# 通り越す
# 買い足す
# 突き抜ける
# 言い合う
# 詰る
# 押し下げる
# 勘繰る
# 雇い入れる
# 減ずる
# 立ち至る
# 負け越す
# 吸い付く
# 撫で回す
# 縊り出す
# 泡立てる
# ぶくる
# 住み替える
# 過ぎ行く
# 泊める
# 早まる
# 染み付く
# 出歩く
# 告る
# 溶け出す
# 選り分ける
# 擦り寄る
# 煮える
# 飽き足る
# 撒き散らす
# 掛け合わせる
# 偽り飾る
# 掻き穿る
# 生う
# 差さる
# 覗き返す
# たむろう
# 惚れる
# 疼く
# 降らす
# 並べ直す
# 居流れる
# 補い合う
# 交じり合う
# 葬り去る
# 晴れ上がる
# 垂れ込む
# 掴み取る
# 浚う
# 崩し掛ける
# ちぎれる
# 照る
# 被り直す
# 巻き上がる
# 責め殺す
# 満ち足りる
# 混じり合う
# 火照る
# 食らい付く
# 燃え上がる
# 撫で下ろす
# 腫れ上がる
# 焼き切れる
# 逃げ惑う
# 吹き上がる
# 刳れる
# 賭する
# 言わす
# 買い受ける
# 屈する
# 言付かる
# 移し替える
# 慮る
# 訝る
# 落ち合う
# 覗き見る
# 睨め回す
# 踏み越える
# まどろむ
# 思い巡らす
# 起き出す
# 張り裂ける
# 揺らせる
# 急かす
# 並べ入れる
# 零れ出す
# ぐずつく
# 触れ回る
# 絶やす
# 炙り出す
# 張り合わせる
# 穿かす
# 荒む
# 叩き殺す
# 狩り出す
# 揺すぶる
# 引っ括める
# 凍て付く
# 切り立てる
# 追い返す
# 誘い込む
# 待ち伏せる
# 書き残す
# 突き刺さる
# 炊き上がる
# 刮げ落とす
# 涼む
# 寝違える
# しゃくる
# ずれ落ちる
# 伏す
# 得する
# 塗り込む
# 平伏す
# 話し歩く
# 取っ捕まえる
# 掠れる
# 紡ぎ合わさる
# もぎ取る
# 絡まり合う
# 鬩ぎ合う
# 渡り合う
# 愛し合う
# 垂れ込める
# 寝直す
# びびる
# 芽吹く
# 茹だる
# ミスる
# 付け合う
# 焼き付く
# がらる
# 着直す
# 打ち倒れる
# トラブる
# 候う
# 集い合う
# 愚痴る
# 埋め戻す
# 託ける
# 遣らす
# 彷徨く
# 侍る
# 罷る
# 没する
# 温む
# 群れる
# 携え帰る
# 点てる
# 商う
# 押っ取る
# 降り積もる
# 包み隠す
# 巻き起こる
# 仄めく
# 扠置く
# 思い沈む
# 思い煩う
# 奪い返す
# 走り抜ける
# 頽れ去る
# 退る
# 突き出る
# 突き通す
# 作り込む
# 選び抜く
# 遣り掛ける
# 持ち去る
# 乗せ替える
# 弄する
# 振り切る
# 押し立てる
# 読み掛ける
# 名乗り出る
# 舞い込む
# 熱り立つ
# 引きちぎる
# 揺るがす
# 聞き届ける
# 抉じ開ける
# 摩り替わる
# 貸し切る
# 手慣れる
# 生い茂る
# 連れ帰る
# 咲き誇る
# 湧き出す
# 負わす
# 塗り潰す
# 指し示す
# 選び取る
# あやかる
# 仕立て上げる
# 見晴らす
# 飲み歩く
# 掻き鳴らす
# 死に別れる
# 煮崩れる
# 労わり合う
# 生き返る
# 屈み込む
# 引き合う
# 揺する
# 繰り上がる
# ずれ込む
# そぐう
# 諮る
# 燥ぐ
# 打ち解ける
# 這い回る
# 泳ぎ回る
# 配り回る
# 潤す
# 盛り付ける
# 上向く
# 脈打つ
# 押し遣る
# 拾い上げる
# 裏返す
# 買い被る
# 擦り抜ける
# くすむ
# 取り回す
# 飛び去る
# 苔むす
# つまされる
# 刻み込む
# 召し抱える
# 繋ぎ直す
# 掛け継ぐ
# 有り触れる
# 絡まる
# 問い直す
# 損する
# 仕舞い込む
# 言い回す
# 押し殺す
# 見合わせる
# 食い繋ぐ
# 穿つ
# 揺れ合う
# 盾突く
# 繰り入れる
# 虐げる
# 背負わす
# 言い当てる
# 煮え滾る
# 疲れ来る
# 打ち落とす
# 成り済ます
# 煮え繰る
# 畏まる
# 勝ち進む
# 回し入れる
# 見向く
# 叩き合う
# 見誤る
# 似せる
# 塗りたくる
# 染み入る
# 絶する
# 抱き上げる
# 漕ぎ出す
# 捩じ曲がる
# 漕ぎ進む
# 戯れ付く
# 引っ繰り返る
# 跳ね継ぐ
# 抉る
# 利かす
# 罰する
# 撥ね飛ばす
# 繋がり合う
# 染み出る
# 突き崩す
# 攻め落とす
# 抱き起こす
# 滴る
# 痩せ細る
# 雪崩れる
# 転げ落ちる
# 滑り落ちる
# 飛び退く
# 煮詰まる
# 差し控える
# 彫り上げる
# 溶き解す
# 零れ出る
# 逃げ延びる
# 織り込む
# 弥増す
# 引き比べる
# 頼み入れる
# 詫びる
# 打ち立てる
# 悩み苦しむ
# 走り込む
# 待ち焦がれる
# 乱す
# 取り縋る
# 狭まる
# 逆立つ
# 抜け出る
# 切れ込む
# 蒸し上がる
# 競り負ける
# 諫める
# 差し迫る
# 言い添える
# 持ち替える
# 塗す
# 駄弁る
# 売り切れる
# 使い余す
# 聞き入る
# 乗っかる
# 抜き取る
# 突っ撥ねる
# 乗り付ける
# 張り詰める
# 喜び掛ける
# 掬い上げる
# 弾き出す
# たじろぐ
# 継ぎ足す
# 抜きん出る
# 見失う
# 繰り延べる
# 捻り出す
# 戦く
# 取り違える
# 引き抜く
# 打ち合う
# 抱き寄せる
# 差し戻す
# 稼ぎ出す
# 蹴り上げる
# 消し去る
# 捌ける
# ぼやく
# 取っちめる
# 使い古す
# 編み出す
# 並べ代える
# 戻し入れる
# 入れ直す
# 項垂れる
# 思い起こす
# 銘打つ
# 嗅ぎ取る
# 学び合う
# 踏み倒す
# 吸い寄せる
# 居直る
# 言い負かす
# 凭れ合う
# 打ち返す
# 走り負ける
# 休する
# 体する
# 寝返る
# 抱え上げる
# しろしめす
# 遣わす
# 折り返す
# パニクる
# 焼け死ぬ
# 引き落とす
# 吹き返す
# 掘り進む
# 失い掛ける
# 差し入れる
# 散らかす
# 追い上げる
# 焦げ付く
# 薄らぐ
# 読み耽る
# 叩き壊す
# 湛える
# 歌い掛ける
# 奉る
# 振り付ける
# 付け替える
# 打ち崩す
# 注がす
# 許し合う
# 呪う
# 殉ずる
# 支払わす
# 掠め取る
# 描き分ける
# 笑い掛ける
# 居残る
# 猛り狂う
# 振り下ろす
# 刺し殺す
# 織り成す
# 読み替える
# 懐く
# 選りすぐる
# 筋張る
# ぐらつく
# 響き合う
# 分かり合う
# 絞り掛ける
# 茹で上げる
# 竦む
# 引き止める
# 解き放つ
# 振り合う
# 聞き付ける
# 打ち負かす
# 押し垂れさせる
# 掻き出す
# 照り輝く
# 数え拾う
# 乗り回す
# 輝かす
# 寄せ合う
# 塗り分ける
# 関わり合う
# 突き砕く
# 立て替える
# 担わす
# 妬む
# 塗れる
# 有り余る
# 滑り下りる
# 被さる
# 訝しむ
# 捜し当てる
# 清める
# 競り落とす
# 干上がる
# 論う
# 諂う
# 引き剥ぐ
# 遣り込める
# 満ち溢れる
# 絞り出す
# くぐもる
# 宣う
# あてがう
# 照り付ける
# 寝かし付ける
# 見せ合う
# 飼い慣らす
# 捏ち上げる
# 痩せこける
# 殴り殺す
# 遣り潰す
# 干涸びる
# 伸す
# 乗っける
# ささくれ立つ
# 凄む
# らりる
# 殴り掛かる
# 鼻白む
# 盗み見る
# 窄める
# 絞り取る
# 勇む
# 伸ばし掛ける
# 耽る
# 縮まる
# 啜り上げる
# 見咎める
# 並外れる
# 振り替える
# 固まり掛ける
# 覆る
# 切り下げる
# 遭わす
# 降り止む
# 寝取る
# 切り裂く
# 仕組む
# 擦り減らす
# 負かせる
# 怪しむ
# 教え込む
# 奮い立つ
# 嘆き悲しむ
# 打ち捨てる
# 騒ぎ立てる
# 生かし合う
# 明け渡す
# 与え返す
# 眠りこける
# 押し伏せる
# 飛び起きる
# 恍ける
# 捻くれる
# 惑う
# 扱き下ろす
# 捲れる
# 打ち拉ぐ
# 立ち働く
# 蟠る
# 入り組む
# 偏する
# 入り交じる
# 言い分ける
# 存する
# 飛び離れる
# 投げ捨てる
# 飢え苦しむ
# 立ち戻る
# 植わる
# 喜び笑う
# 食べ歩く
# 運び去る
# 挫く
# 抱き付く
# 息衝く
# 押さえ込む
# 組み合う
# 組み直す
# 屠る
# 売り逃す
# 出しゃばる
# 消え行く
# のたうち回る
# 開き掛ける
# 自惚れる
# 炒る
# 漏れ伝わる
# ナビる
# 轟く
# 噎せ返る
# 縫い上げる
# 面食らう
# 潤む
# 降り懸かる
# 降り頻る
# 拭い取る
# 皮肉る
# 酔い潰れる
# 打ち上がる
# 交尾む
# 照らし合わせる
# 競り勝つ
# 揉み解す
# 見飽きる
# 冷ます
# 打ち放す
# 掻き分ける
# 回し込む
# 溢れ出す
# へし曲げる
# 書き留める
# 繋ぎ止める
# 迷い込む
# 使い回す
# 買い漁る
# 排する
# 弄くり回す
# 揉み込む
# 散らかる
# 打ち消す
# 抓る
# 履き替える
# 掻き取る
# 眠り呆ける
# 欹てる
# 揺らめく
# 言い捨てる
# 惚ける
# 解れる
# テンパる
# 貪り読む
# 聞き流す
# 透かす
# がめる
# 借り受ける
# 牛耳る
# 当て込む
# 怒り狂う
# 逸する
# 浮かす
# 売り捌く
# 縫い込む
# 出っ張る
# 繰る
# 事足りる
# 挟み込む
# 奮い立たす
# 歌い踊る
# 干し上がる
# 事寄せる
# あぐねる
# 煎じ詰める
# がかる
# 解き解す
# 蒼む
# 押し破る
# 泣き止む
# 剥げ落ちる
# 摘み取る
# べた付く
# 掻き攫う
# 塗り固める
# 萎れる
# 漲る
# 招き入れる
# 植え込む
# 鄙びる
# ぶち切れる
# 打っぱなす
# 打ち付ける
# 塞ぎ合う
# 利する
# 抗う
# 浮かれ踊る
# 焼き上げる
# 慣らす
# 渡り歩く
# 回り回る
# 遣っ付ける
# 泣き崩れる
# 磨り潰す
# 借り換える
# 浮かれる
# 打ち払う
# 投げ入れる
# 語り起こす
# 分け入る
# 乗り捨てる
# 浮腫む
# 禿げ上がる
# がなる
# 叩きのめす
# 甚振る
# 若返る
# 突っ掛かる
# 飛び乗る
# 背負い込む
# 締め込む
# 剥げる
# 淀む
# 拗ねる
# 崩ずる
# 掻い摘む
# 萌える
